# %% [markdown]
# <h1><center>Laboratorio 3: El Pandas no muerde (act. I) 🐼</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesor: Matías Rojas y Mauricio Araneda
# - Auxiliar: Ignacio Meza D.
# - Ayudante: Rodrigo Guerra

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Roberto Barceló

# %% [markdown]
# ### **Link de repositorio de GitHub:** `https://github.com/RobertoBarcelo/Lab_PCPCD_MDS7202/blob/main/Laboratorio_3.ipynb`
#
# ---

# %% [markdown]
# ### Reglas:
#
# - **Grupos de máximo 2 personas**
# - **Ausentes** deberán realizar la actividad solos.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Prohibidas las copias.
# - Pueden usar cualquer matrial del curso que estimen conveniente.

# %% [markdown]
# ### Temas a tratar
#
# - Introducción al manejo de datos tabulares por medio de la libreria `pandas`.

# %% [markdown]
# ### Objetivos principales del laboratorio
#
# - Entender, aplicar y aprovechar las ventajas que nos ofrece la libreria `pandas` para manejar datos tabulares.
# - Aprender a utilizar la documentación de pandas (y en general, de cualquier librería de python) como también a buscar soluciones en la web.
#
# > **Nota**: El laboratorio deberá ser desarrollado sin el uso indiscriminado de iteradores nativos de python (aka "for", "while"). La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `pandas`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre DataFrames.

# %% [markdown]
# ### Librerias utiles para el Lab 😸

# %%
# Libreria Core del lab.
import numpy as np
import pandas as pd
from IPython.display import display

#Libreria para plotear
# !pip install --upgrade plotly
import plotly.express as px

# Librerias utiles
from sklearn.preprocessing import StandardScaler
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.2 MB 25.5 MB/s
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# ...

# %% [markdown]
# # 1. Rendimiento en Estudiantes 📚

# %% [markdown]
# Para este laboratorio deberán trabajar con el dataset `students_grades.json` el cual contiene información sobre el rendimiento de alumnos en distintos ramos.
# El objetivo principal será el de realizar un trabajo de limpieza de prepración y exploración de datos utilizando exclusivamente `DataFrames` y sus métodos asociados.

# %%
# Si usted está utilizando Colabolatory le puede ser útil este código para cargar los archivos.
try:
    from google.colab import drive
    drive.mount("/content/drive")
    path = '/content/drive/MyDrive/MDS7202_LPCPCD/Lab 3/students_grades.json'
except: 
    print('Ignorando conexión drive-colab')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1.1 Carga e Inspección de Datos [1.5 Puntos]
#
#
# <p align="center">
#   <img src="https://drive.google.com/uc?export=view&id=1hZZaPQlZe4VupFOXt76_wjuUA5NpUhrw" width="300" height="300">
# </p>

# %% [markdown]
# *Don Caguayo*, rector de la Universidad de la Cachaña, les comenta que actualmente la Universidad no tiene una subdirección de análisis de datos, pero que tiene un gran interés en formar una. Es por esto, que se contacta con ud. y su equipo para iniciar de forma exploratoria diversas tareas de análisis y consolidación de datos respectivos al rendimiento de sus alumnos.
#
# Previo a su primera reunión con el rector, el rector le envía una copia de la base de datos, la cuál a usted y su equipo le encantaría examinar. Para esto, la primera tarea que debe realizar es abrir y cargar el dataset.
#
#
# > **Notar que es sumamente importante el formato que posee cada columna** para su manipulación y que posiblemente ustedes deberán especificar algunos tipos de datos a mano. Ver la documentación del método `read_json` para mayor información.
#
# A continuación se muestra un ejemplo de los dos primeros registros del dataset:
#
# ```json
# [
#   {
#     "names": "Rita Courtney",
#     "gender": "female",
#     "race/ethnicity": "group B",
#     "parental level of education": "some high school",
#     "lunch": "standard",
#     "test preparation course": "none",
#     "math score": 37,
#     "reading score": 46,
#     "writing score": 46
#   },
#   {
#     "names": "Madeline Fuller",
#     "gender": "female",
#     "race/ethnicity": "group C",
#     "parental level of education": "some high school",
#     "lunch": "standard",
#     "test preparation course": "none",
#     "math score": 124,
#     "reading score": 142,
#     "writing score": 142
#   }
# ]
# ```

# %%
df_grades = pd.read_json(path, typ='frame')

# %%
df_grades.dtypes
# Out:
# names                          object
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                     object
# reading score                  object
# writing score                  object
# dtype: object

# %% [markdown]
# <p align="center">
#   <img src="https://i.giphy.com/media/4FQMuOKR6zQRO/giphy.webp">
# </p>
#
#
# Posteriormente, el rector les comenta que la sección de TI posee una base de datos con más de **875** filas, en donde cada fila representa un alumno matriculado. Sin embargo, cree fuertemente que existen errores en esta: solo tiene registro de **875** matriculas. Por este motivo, especula que se han realizado malas prácticas al registrar dichos datos.
#
# En consecuencia, el rector les solicita a ustedes como tarea inicial que exploren la base de datos y encuentre posibles falencias dentro de sus registros. Para esto, usted debe estar al tanto que las notas están en una escala que van del **0 al 100** (porcentaje de logro) y **no es posible que un alumno haya dado más de una vez el mismo examen**. Cualquier alumno que posea un valor diferente a esta escala, debería ser eliminado de la base de datos.

# %% [markdown]
# > **Instrucciones**
#
# **Cree una función** que tome un `DataFrame` y que le permita revisar si las diferentes variables que lo componen son coherentes y si es posible observar anomalías en estas.
#
# **To-Do**
# 1. [X] Imprimir un mensaje con las dimensiones del Dataframe.
# 2. [X] Imprimir un mensaje con los nombres de las columnas que conforman el DataFrame.
# 3. [X] Mostrar los primeros 5, los últimos 5 elementos del DataFrame y realice un muestreo de 5 elementos de forma aleatoria.
# 4. [X] Mostrar una descripción rápida de las variables numéricas del DataFrame (utilice un método visto en clases).
# 5. [X] Imprimir un mensaje con la cantidad de valores nulos (investigue el método `isna()` y `sum()` de los DataFrames).
# 6. [X] Imprimir un mensaje que detalle la cantidad de valores unicos (investigue `nunique()`) .
# 7. [X] Imprimir un mensaje con el total de filas que contengan nombres duplicados (investigue `duplicated()` y su parámetro `subset`).
# 8. [X] Mostrar las filas que contengan nombres sean duplicados (investigue `duplicated()` y su parámetro `subset`).
# 9. [X] A traves de `.plot.box()` plotear el boxplot de las notas. De ser necesario, invetigue como funcionan los gráficos de caja (esta sección es provista).
# 10. [X] Finalmente responda la siguiente pregunta:
#
# > ¿Que anomalias es posible observar de los datos que componen el DataFrame? ¿Existen valores nulos o duplicados? ¿Qué puede interpretar de la distribución de las notas en el boxplot? (), comente esto en la celda ubicada debajo de **justificación**.
#
# > **Nota:** Para imprmir utilice `print(...)`. Para mostrar `DataFrames`, utilice `display(...)` ya que este permite mostrar estos elementos como tablas.
#
# > **Nota 2:** Utilice la documentación de [pandas](https://pandas.pydata.org/docs/index.html) como también StackOverflow para resolver cualquier problema o inconveniente.
#
# > **Nota 3:** Si no ha trabajado con boxplot antes, el siguiente link puede serle de mucha ayuda: [boxplot](https://medium.com/dayem-siddiqui/understanding-and-interpreting-box-plots-d07aab9d1b6c)

# %% [markdown]
# **Respuesta:**

# %%
from pandas.core.common import random_state
def exploratory_data_analysis(dataframe):
  # convertimos algunas variables a variables numericas
  dataframe['math score'] = pd.to_numeric(dataframe['math score'])
  dataframe['reading score'] = pd.to_numeric(dataframe['reading score'])
  dataframe['writing score'] = pd.to_numeric(dataframe['writing score'])
  # Imprimimos las dimensiones del dataframe
  dims = dataframe.shape
  print(f'1.- El dataframe tiene {dims[0]} filas y {dims[1]} columnas')
  print('')
  # Imprimimos un mensaje con los nombres de las columnas del dataframe
  print('2.- El DataFrame esta compuesto por las siguientes columnas:', list(dataframe.columns))
  print('')
  # mostrar los primeros 5 y los ultimos 5 elementos del dataframe y realizar un muestreo de 5 elementos aleatorios
  df_p_5 = dataframe.head(5)
  df_u_5 = dataframe.tail(5)
  df_al_5 = dataframe.sample(5, random_state=123)
  print('3.- Ejemplos de filas del DataFrame:')
  print('')
  print('Primeras 5 filas:')
  display(df_p_5)
  print('')
  print('Últimas 5 filas:')
  display(df_u_5)
  print('')
  print('Muestreo aleatorio de 5 filas:')
  display(df_al_5)
  print('')
  # Mostrar las variables numericas del dataframe
  print('4.- Descripción numérica del Dataframe:')
  decrip = dataframe.describe()
  display(decrip)
  print('')
  # contamos la cantidad de valores nulos en el dataframe
  print('5.- Cantidad de valores nulos por columna:')
  nul_val = dataframe.isna().sum()
  print(nul_val)
  print('')
  # contar la cantidad de valores unicos en el dataframe
  print('6.- Cantidad de valores únicos por columna:')
  uniq_val = dataframe.nunique()
  print(uniq_val)
  print('')
  # contar la cantidad de nombres duplicados en el dataframe
  name_duplicados = dataframe.duplicated(subset = ['names']).sum()
  print(f'7.- Presenta un total de {name_duplicados} filas con nombres duplicados.')
  print('')
  # mostrar las filas con los nombres duplicados 
  duplicados = dataframe[dataframe.duplicated(subset = ['names'])]
  print('8.- Las filas con nombres duplicados son:')
  display(duplicados)
  print('')
  # ploteamos el box plot de las notas
  print('9.- Boxplot de notas:')
  fig = px.box(dataframe[['math score', 'reading score', 'writing score']])
  fig.show()
  pass

# %% [markdown]
# **Justificación:**

# %% [markdown]
# ```
# ¿Que anomalias es posible observar de los datos que componen el DataFrame? ¿Existen valores nulos o duplicados? ¿Qué puede interpretar de la distribución de las notas en el boxplot?
#
# En primera instancia podemos observar algunas anomalías bastante aparentes:
#
# 1) Existen notas imposibles en los exámenes (donde obtienen mas de 100).
#
# 2) Existen alumnos que no tienen notas en algunos exámenes, obteniendo campos vacíos.
#
# 2) Existen 247 instancias en donde se encuentran dos registros de alumnos con el mismo nombre.
#
# Con respecto a los boxplot, observamos que existen outliers en los datos, considerando que los datos no distribuyen de forma normal, tendremos que se encuentran cargados hacia sus máximos, los cuales se encuentran fuera de las escalas permitidas. Sabemos que al menos el 75% de los datos (Dentro de el cuartil 3), se encuentran correctamente anotados Para todas las pruebas.
# ```

# %% [markdown]
# **Respuesta Esperada:**

# %%
exploratory_data_analysis(df_grades)
# Out:
# 1.- El dataframe tiene 1400 filas y 9 columnas
#
# 2.- El DataFrame esta compuesto por las siguientes columnas: ['names', 'gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'math score', 'reading score', 'writing score']
#
# 3.- Ejemplos de filas del DataFrame:
#
# Primeras 5 filas:
#               names  gender race/ethnicity parental level of education  \
# 0     Rita Courtney  female        group B            some high school
# 1   Madeline Fuller  female        group C            some high school
# 2     Daniel Rester    male        group E          associate's degree
# 3  Charles Linstrom    male        group A           bachelor's degree
# 4    Geraldine Hale  female        group A          associate's degree
#
#       lunch test preparation course  math score  reading score  writing score
# 0  standard                    none        37.0           46.0           46.0
# ...

# %% [markdown]
# ## 1.2 Limpieza de Datos [1 punto]
#
# <p align="center">
#   <img src="https://blogdatlas.files.wordpress.com/2020/07/datlas_mx_blog_limpieza_bds_data-scrubbing-service.gif">
# </p>

# %% [markdown]
# En base a lo realizado anteriormente, realice una limpieza de los dataset. Asuma los supuestos señalados en la pregunta anterior para limpiar el `DataFrame` y cree una función que le permita limpiar los datos. Una vez limpiado cada uno de los `DataFrames` compruebe nuevamente los datos con la función creada en la sección 1.1.
#
# **To-Do:**
#
# - [X] Crear función que permita limpiar el dataset.
# - [X] Comprobar que no existen anomalías en los datos a traves de la función de la sección 1.1.
#
# **Hint**
#
# Puede ser útil los métodos ```.drop_duplicates()``` y ```.dropna()``` como también utilizar queries con máscaras booleanas.

# %%
def clean_data(dataframe):
  df = dataframe.copy()
  #eliminamos filas con valores nulos
  df.dropna()
  # como los valores en los score no corresponden a objetos, tendremos que uutilizar drop en base a los indices para eliminar las filas con valores nan del dataframe
  ind = df[(df['math score'].isna()) | (df['reading score'].isna()) | (df['writing score'].isna())].index
  df = df.drop(index = ind)
  #eliminamos filas con nombres duplicados
  df.drop_duplicates(subset = ['names'], keep="first", inplace=True)
  #eliminamos filas con notas fuera de rango
  # indicies de columnas que cumplen la condicion de notas
  indices = df[(df['math score']>100) | (df['reading score']>100) | (df['writing score']>100)].index
  df = df.drop(index = indices)
  return df

# %% [markdown]
# **Respuesta:**

# %%
df_grades = clean_data(df_grades)
df_grades
# Out:
#                  names  gender race/ethnicity parental level of education  \
# 0        Rita Courtney  female        group B            some high school
# 3     Charles Linstrom    male        group A           bachelor's degree
# 5          Brian Young    male        group C            some high school
# 6       Howard Jimenez    male        group E            some high school
# 7         Wayne Wilson    male        group B            some high school
# ...                ...     ...            ...                         ...
# 1392     Richard Young    male        group D                 high school
# 1394     Wanda Russell  female        group B                 high school
# 1396    Marina Zeigler  female        group C           bachelor's degree
# 1397     Laurie Carter  female        group B            some high school
# 1399      Amanda Perez  female        group A                 high school
#
#              lunch test preparation course  math score  reading score  \
# ...

# %%
exploratory_data_analysis(df_grades)
# Out:
# 1.- El dataframe tiene 901 filas y 9 columnas
#
# 2.- El DataFrame esta compuesto por las siguientes columnas: ['names', 'gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'math score', 'reading score', 'writing score']
#
# 3.- Ejemplos de filas del DataFrame:
#
# Primeras 5 filas:
#               names  gender race/ethnicity parental level of education  \
# 0     Rita Courtney  female        group B            some high school
# 3  Charles Linstrom    male        group A           bachelor's degree
# 5       Brian Young    male        group C            some high school
# 6    Howard Jimenez    male        group E            some high school
# 7      Wayne Wilson    male        group B            some high school
#
#       lunch test preparation course  math score  reading score  writing score
# 0  standard                    none        37.0           46.0           46.0
# ...

# %% [markdown]
# > Utilice la función creada en el punto 1.1 para verificar sus resultados.

# %% [markdown]
# **Justificación:**

# %% [markdown]
# ```
# Vemos, mediante la función creada en 1.1, que ya no hay datos duplicados, nulos o con notas que no están dentro del rango
# ```

# %% [markdown]
# ## 1.3 Trabajando con Datos
#
# <p align="center">
#   <img src="https://media3.giphy.com/media/YQitE4YNQNahy/giphy-downsized-large.gif">
# </p>

# %% [markdown]
# ### 1.3.1 Transformación de notas a "Nota Chilena" [0.5 Puntos]

# %% [markdown]
# En una de las reuniones con Don Caguayo este les comenta su intención de pasar todas sus notas a la "Escala Chilena". Para esto les facilita la siguiente ecuación:
#
# $$Nota \, Chilena= \% \, de \, logro*0.06 + 1$$
#
# Utilizando la ecuación entregada, cree una función que le permita pasar a la escala Chilena las notas que se escapan del rango [1,7] y entregue las notas redondeadas al segundo decimal.
#
# **To-Do**
#
# - [X] Tranforme los valores a la escala chilena.

# %% [markdown]
# **Respuesta:**

# %%
def nota_chilena(dataframe_in, columna):
  # creamos una copia del dataframe de entrada
  df = dataframe_in.copy()
  # aplicamos el calculo de la nota a la chilena
  df[columna] = df[columna].apply(lambda x: x*0.06 + 1)
  # retornamos el dataframe modificado
  return df

# %% [markdown]
# ### 1.3.2 Obtención de promedio de alumnos [0.5]

# %% [markdown]
# Con todas las notas adjuntadas, la prestigiosa Universidad De la Cachaña necesita obtener el promedio general de cada uno de los alumnos. Para esto se le solicita que calcule el promedio con cada una de las asignaturas y el promedio se anexe como una nueva columna al final del DataFrame original. Cabe señalar que las notas deben ser redondeadas al segundo decimal.
#
# **To-Do:**
# - [ ] Crear función que nos permite obtener el promedio de cada uno de los alumnos y anexar esta información en el DataFrame original.

# %% [markdown]
# **Respuesta:**

# %%
def alumnos_promedio(dataframe_in):
  # calculamos las notas en formato chileno
  df = nota_chilena(dataframe_in,'math score')
  df = nota_chilena(df,'reading score')
  df = nota_chilena(df,'writing score')
  df['GPA'] = (df['math score'] + df['reading score']+ df['writing score'])/3
  return df

# %% [markdown]
# **Respuesta Esperada:**

# %%
df_grades = alumnos_promedio(df_grades)
df_grades.head(15)
# Out:
#                names  gender race/ethnicity parental level of education  \
# 0      Rita Courtney  female        group B            some high school
# 3   Charles Linstrom    male        group A           bachelor's degree
# 5        Brian Young    male        group C            some high school
# 6     Howard Jimenez    male        group E            some high school
# 7       Wayne Wilson    male        group B            some high school
# 8   Jonathan Clingan    male        group D                some college
# 9       William Tang    male        group D          associate's degree
# 13       Mikki Amaya  female        group A                 high school
# 15     Gerald Wilson    male        group A          associate's degree
# 16       Damon Mckee    male        group E                 high school
# 17      Sophia Bijou  female        group D            some high school
# 19   Monica Schwartz  female        group B          associate's degree
# ...

# %% [markdown]
# ### 1.3.3 Reprobados y Destacados [1.5 Punto, 0.5 Cada DataFrame]

# %% [markdown]
# Contentos con su desempeño, la Universidad les solicita que obtengan los alumnos quienes han reprobado el año y los que han tenido desempeño de destacado. Para esto se considerará que un alumno ha reprobado el año cuando el promedio de notas es inferior a 4.0 en la Escala Chilena, y se considerará destacado si posee notas superiores a 5.8 en todas las asignaturas (o sea notas superiores a 5.8 en `math score`, `reading score` y `writing score`).
#
# Cree una función que permita obtener tres Dataframes:
# - El primero deberá poseer solamente los alumnos que han reprobado en la prestigiosa universidad.
# - El segundo debe entregar un DataFrame similar al original, pero marcado con una "R" el promedio de notas de los alumnos reprobados.
# - El tercero será un Data Frame con los alumnos destacados ordenados de mayor a menor.
#
# **To-Do:**
#
# - [X] Obtener DataFrame con los alumnos que reprobaron el año.
# - [X] Obtener DataFrame similar al original, pero marcados con una "R" el atributo GPA de los alumnos reprobados.
# - [X] Obtener DataFrame con los alumnos destacados ordenados de mayor a menor.

# %% [markdown]
# **Respuesta:**

# %%
def reprobados_destacados(dataframe_in):
  # reprobados
  df_reprobados = dataframe_in.copy()
  ind = df_reprobados[df_reprobados['GPA'] >= 4.00].index
  df_reprobados = df_reprobados.drop(index = ind)

  # dataframe reprobados marcados con R
  df_R = dataframe_in.copy()
  df_R.loc[df_R['GPA'] < 4, 'GPA'] = 'R'

  # Dataframe con los alumnos destacados de mayor a menor
  df_D = dataframe_in.copy()
  ind_destacados = df_D[df_D['GPA'] < 5.89].index
  df_D = df_D.drop(index = ind_destacados)
  df_D = df_D.sort_values(by = 'GPA', ascending = False)
  return df_reprobados, df_R, df_D

# %%
dataframe1, dataframe2, dataframe3 = reprobados_destacados(df_grades)
dataframe1
# Out:
#                 names  gender race/ethnicity parental level of education  \
# 0       Rita Courtney  female        group B            some high school
# 13        Mikki Amaya  female        group A                 high school
# 26      Samuel Dougal    male        group C             master's degree
# 55    Rodger Talavera    male        group B                 high school
# 63     Morris Johnson    male        group A          associate's degree
# ...               ...     ...            ...                         ...
# 1371   Charles Harian    male        group C            some high school
# 1373    Wendy Gunnell  female        group D            some high school
# 1389      Diana Costa  female        group C                 high school
# 1391      Amy Sieving  female        group C                 high school
# 1394    Wanda Russell  female        group B                 high school
#
#              lunch test preparation course  math score  reading score  \
# ...

# %%
dataframe2
# Out:
#                  names  gender race/ethnicity parental level of education  \
# 0        Rita Courtney  female        group B            some high school
# 3     Charles Linstrom    male        group A           bachelor's degree
# 5          Brian Young    male        group C            some high school
# 6       Howard Jimenez    male        group E            some high school
# 7         Wayne Wilson    male        group B            some high school
# ...                ...     ...            ...                         ...
# 1392     Richard Young    male        group D                 high school
# 1394     Wanda Russell  female        group B                 high school
# 1396    Marina Zeigler  female        group C           bachelor's degree
# 1397     Laurie Carter  female        group B            some high school
# 1399      Amanda Perez  female        group A                 high school
#
#              lunch test preparation course  math score  reading score  \
# ...

# %%
dataframe3
# Out:
#                   names  gender race/ethnicity parental level of education  \
# 1352      Sandra Pompey  female        group E          associate's degree
# 677       Richard Pryor    male        group E           bachelor's degree
# 384   Elizabeth Beasley  female        group E           bachelor's degree
# 475           Emma Gray  female        group E           bachelor's degree
# 279        Emma Brasher  female        group D            some high school
# ...                 ...     ...            ...                         ...
# 145      Katrina Wilcox  female        group E           bachelor's degree
# 620      Richard Taylor    male        group B          associate's degree
# 1170        David Lemke    male        group E                some college
# 743         Terry Davis    male        group D            some high school
# 96          Harry Berry    male        group B          associate's degree
#
#          lunch test preparation course  math score  reading score  \
# ...

# %% [markdown]
# **Respuesta:**

# %% [markdown]
# ```
# Escriba aqui su respuesta
# ```

# %% [markdown]
# ### 1.3.4 Consultas de Alumnos [0.5 Puntos]

# %% [markdown]
# Algunos padres (extremadamente entrometidos y...) preocupados por el desempeño de sus hijos, desean saber estos han aprobado o no el año. Como la tarea de buscar a mano cada uno de estos alumnos en el `DataFrame` resulta demasiado tedioso, el rector le solicita crear una función que tenga como entrada el `DataFrame` donde se realizará la busqueda y una lista con los nombres de los alumnos, luego la función deberá retornar un `DataFrame` con los nombres de los alumnos y el promedio general de cada uno.
#
# Creada la función busque el promedio general de los siguientes alumnos en el segundo Data frame creado en la sección 1.3.3:
#
# `['Lucille Stanphill','Marcus Mcfarland', 'Matthew Freeman', 'Dana Mojica', 'Paul Hyder', 'Jeffrey Korn', 'Robert Strain',
# 'Ronald Jett', 'Lorena Reed', 'Hazel Posey']`
#
# **Hint:** Puede serle de utilidad utilizar `isin()`.

# %% [markdown]
# **Respuesta:**

# %%
def consulta_gpa(dataframe_in, lista_alumnos):
  df_out = dataframe_in.copy()
  df_out = df_out[df_out['names'].isin(lista_alumnos)]
  df_out = df_out.loc[:,['names','GPA']]
  return df_out


lista_alumnos = [
    "Lucille Stanphill",
    "Marcus Mcfarland",
    "Matthew Freeman",
    "Dana Mojica",
    "Paul Hyder",
    "Jeffrey Korn",
    "Robert Strain",
    "Ronald Jett",
    "Lorena Reed",
    "Hazel Posey",
]
consulta_gpa(dataframe2, lista_alumnos)
# Out:
#                   names   GPA
# 296   Lucille Stanphill  5.94
# 564    Marcus Mcfarland  4.86
# 637     Matthew Freeman     R
# 640         Dana Mojica     R
# 919        Jeffrey Korn  4.54
# 1054      Robert Strain   4.4
# 1065        Ronald Jett     R
# 1068        Hazel Posey     R
# 1195        Lorena Reed     R

# %% [markdown]
# ### 1.3.5 Quintiles de Rendimiento [0.5 Puntos]

# %% [markdown]
# El rector, intrigado por saber si existe una relación entre el nivel educacional de los padres y las notas de sus hijos les plantea estudiar dicha relación. Para esto, les solicita que desde el `DataFrame` que posee a todos los alumnos (`DataFrame` obtenido tras la limpieza), generen una nueva columna que clasifique en quintiles de rendimiento para sus alumnos: `['Bajísimo', 'Bajo', 'Medio', 'Alto', 'Muy alto']`. (investigar `qcut()`)
#
# Hecho esto, grafique a través de un scatter plot el nivel educacional de los padres v/s el promedio de los alumnos, utilice los cuantiles generados anteriormente para mostrar en que cuantil se encuentra cada uno de los datos.
#
# Realizado el grafico, responda la siguiente pregunta: **¿Es posible visualizar alguna tendencia en el gráfico?.**

# %% [markdown]
# **Respuesta:**

# %%
# Código para quintiles 
# La variable que contenga los quintiles debe llamarse GPA cuantiles para que el gráfico funcione.
def GPA_cuantiles(dataframe_in):
  # definimos una funcion que recibe un dataframe y , usando qcut, separa los valores de GPA en 5 quintiles. Clasificandoolos en base a sus labels. Devolviendo otro dataframe
  bins_labels = ['Bajísimo', 'Bajo', 'Medio', 'Alto', 'Muy alto']
  df_out = dataframe_in.copy()
  df_out['GPA cuantiles'] = pd.qcut(df_out['GPA'], q=5, labels = bins_labels)
  return df_out

df_grades = GPA_cuantiles(df_grades)
# Código de gráfico 
fig = px.scatter(
    df_grades.sort_values(by="GPA"),
    x="GPA",
    y="parental level of education",
    hover_data=["gender"],
    color="GPA cuantiles",
    title="GPA por Nivel de educación de los padres",
    color_discrete_sequence=["tomato", "orange", "yellow", "greenyellow", "green"]
)

fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ```
# En el gráfico podemos ver que existe una correlación entre el nivel educacional de los padres y el rango de notas esperadas en el GPA. Si los padres tienen un nivel educacional mas alto, es mas probable que la hija o el hijo apruebe sus exámenes y obtenga un GPa por sobre 4.
#
# En cambio, la varianza de notas de los hijos cuando los padres tienen un nivel educacional mas bajo es mucho mayor.
#
# Así mismo, la frecuencia de hijos con mejores notas tiende a aumentar a medida que los padres tienen un mayor nivel de educación.
# ```

# %% [markdown]
# # Conclusión
# Eso ha sido todo para el lab de hoy, recuerden que el laboratorio tiene un plazo de entrega de una semana. Cualquier duda del laboratorio, no duden en contactarnos por mail o U-cursos.
#
# <p align="center">
#   <img src="https://media1.tenor.com/images/2f7df460196625edc45b8380d158e5ee/tenor.gif?itemid=16669403">
# </p>

# %% [markdown]
# <br>
# <center>
# <img src="https://i.kym-cdn.com/photos/images/original/001/194/195/b18.png" width=100 height=50 />
# </center>
# <br>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=87110296-876e-426f-b91d-aaf681223468' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
